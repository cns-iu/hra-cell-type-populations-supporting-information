# %% [markdown]
# # Code to generate 2 CSV files for UMAPs (by cell summary and by intersection percentage with anatomical structures)

# %% [markdown]
# ## Import statements

# %%
import pandas as pd
import json
import re

# %% [markdown]
# ## Global variables

# %%
hra_pop_version = "0.8.3"

# %% [markdown]
# ## Global methods

# %%
def strip_reference_organ(reference_organ, as_label):
    """removes a set of predefined strings form a reference organ and returns a column header

    Args:
        reference_organ (string): an IRI for an organ
        as_label (_type_): a human readable label for an anatomical structure

    Returns:
        header (string): a column header
    """
    to_remove = ['VHF', 'VHM']
    pattern = "|".join(map(re.escape, to_remove))
    organ = re.sub(pattern,'', reference_organ)
    # header = f'{organ} - {as_label}'
    header = f'{as_label}'
    return header

def get_partial_match_key(header, partial_string):
    """Returns a key given a match with a partial string

    Args:
        dict (string): a header
        partial_string (string): a partial key

    Returns:
        key (if match found): a full key that matches the partial string argument
    """
    if partial_string in header:
        return header
    return None  # Return None if no partial match is found

def remove_version(input_string):
    """Removes the version from a reference organ

    Args:
        input_string (string): the reference organ with version

    Returns:
        string : the reference organ without version
    """
    return re.sub(r'V\d+(\.\d+)?', '', input_string)

# %% [markdown]
# ## Load enriched-dataset-graph

# %%
 # Link to atlas-enriched-dataset-graph
atlas_enriched_dataset_graph_file = open("../../hra-pop/output-data/v"+hra_pop_version+ "/atlas-enriched-dataset-graph.jsonld") # biomarkers and cell types

# Opening Jthe JSON-LD file
dataset_graph = json.load(atlas_enriched_dataset_graph_file)

# %% [markdown]
# ## Main

# %%
# initialize result, to be converted to pandas data farme at the end and exported as CSV
result = {
'dataset_id' : [],
'dataset_combinations' : [],
'organ' : [],
'as_item_combinations' : []
}

# construct columns for output
for donor in dataset_graph['@graph']:
  for sample in donor['samples']:
    for collision_summary in sample['rui_location']['all_collisions']:
      for collision_item in collision_summary['collisions']:
        as_label = collision_item['as_label']
        
        # construct AS column header
        header = strip_reference_organ(remove_version(collision_item['reference_organ'].split('#')[1]), as_label)
        
        # add header if not present yet
        if header not in result:
          result[header] = []



# fill in columns
for donor in dataset_graph['@graph']:
  for sample in donor['samples']:
    
    datasets_in_sample = []
    
    # get dataset_id from sample
    for dataset in sample['datasets']:
      result['dataset_id'].append(dataset['@id'])
      datasets_in_sample.append(dataset['@id'])
    
    # get dataset_id from section
    for section in sample['sections']:
      for dataset in section['datasets']:
        result['dataset_id'].append(dataset['@id'])
        datasets_in_sample.append(dataset['@id'])

    # get organ
    result['organ'].append(remove_version(sample['rui_location']['placement']['target'].split('#')[1]))
    
    # get AS percentages
    for collision_summary in sample['rui_location']['all_collisions']:
      result['dataset_combinations'].append(datasets_in_sample)
      
      # get simplified collision items
      as_items = []
      
      for collision_item in collision_summary['collisions']:
        as_items.append(
          {
            'label': collision_item['as_label'],
            'percentage': collision_item['percentage']
          }
        )
        # as_items['label'] = collision_item['as_label']
        # as_items['percentage'] = collision_item['percentage']

      result['as_item_combinations'].append(as_items)
      # define columns to ignore

    ignore_columns = ["dataset_id", "organ", "dataset_combinations", "as_item_combinations"]

    keys_matching_condition = []
    for key in result:
      if key in ignore_columns:
        continue

    # add 0 as default AS collision percentage
    for key in result:
      if key in ignore_columns:
       continue
      else:
        result[key].append(0)

# identify as_item_combinations with the same value
multiple_as_item_combinations = {}

for row in result['as_item_combinations']:
 if str(row) not in multiple_as_item_combinations:
   multiple_as_item_combinations[str(row)] = {
     'occurences' : 1,
     'current_index' : 0,
     'indices_in_rows' : []
     }
 else:
   multiple_as_item_combinations[str(row)]['occurences'] = multiple_as_item_combinations[str(row)]['occurences'] + 1
   multiple_as_item_combinations[str(row)]['indices_in_rows'] = [index for index, value in enumerate(result['as_item_combinations']) if value == row]

for row in list(multiple_as_item_combinations.keys()):
  if multiple_as_item_combinations[str(row)]['occurences'] == 1:
    del multiple_as_item_combinations[str(row)]

# for item in multiple_as_item_combinations:
#   print(f'{item} has: {multiple_as_item_combinations[item]}')

# fill in percentages based on column for all AS intersections per sample/tissue block
for row in result["as_item_combinations"]:
  for key in result:
    if key in ignore_columns:
      continue
    for item in row:
      if item['label'] == key:

      # ALWAYS RETURNS INDEX OF FIRST OCCURENCE! NEED TO ACCOUNT FOR ROWS WITH SAME VALUES!
      # check if row occurs multiple times
        for multiple_combo in multiple_as_item_combinations:
          if str(row) == multiple_combo:
            
            current = multiple_as_item_combinations[str(row)]['current_index']
            print(f'For {str(row)} with {multiple_as_item_combinations[str(row)]}')
            print(f'\t The current index is {current} for {multiple_as_item_combinations[str(row)]}')
            print(f'\t This will return ' + str(multiple_as_item_combinations[str(row)]['indices_in_rows'][current]))
            print()
            i_in_row = multiple_as_item_combinations[str(row)]['indices_in_rows'][current]
   
  
            # print(f'index before ++: {i_in_row}')
      
            multiple_as_item_combinations[str(row)]['current_index'] = multiple_as_item_combinations[str(row)]['current_index'] + 1

            # print(f'index after ++: {i_in_row}')
            
            # print(f"found combo for {str(row)}: {multiple_as_item_combinations[str(row)]}")
            # print(f'index after IF: {index}')
          else:
            i_in_row = result['as_item_combinations'].index(row)
            # print(f'index after ELSE: {index}')
        
        # print(f'post:{i_in_row}')
        result[key][i_in_row] = item['percentage']



print(f"Total datasets: {total}")
print()
# print result for checking
for key in result:
  print(f"Key {key}:\n Length: {len(result[key])},\n Values: {result[key]}")
# Out:
# For [{'label': 'jejunum', 'percentage': 0.103}] with {'occurences': 2, 'current_index': 0, 'indices_in_rows': [0, 98]}
# 	 The current index is 0 for {'occurences': 2, 'current_index': 0, 'indices_in_rows': [0, 98]}
# 	 This will return 0
#
# For [{'label': 'descending colon', 'percentage': 0.883}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [1, 92, 113]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [1, 92, 113]}
# 	 This will return 1
#
# For [{'label': 'superior part of duodenum', 'percentage': 0.026}, {'label': 'descending part of duodenum', 'percentage': 0.032}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [2, 97, 114]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [2, 97, 114]}
# 	 This will return 2
#
# For [{'label': 'superior part of duodenum', 'percentage': 0.026}, {'label': 'descending part of duodenum', 'percentage': 0.032}] with {'occurences': 3, 'current_index': 1, 'indices_in_rows': [2, 97, 114]}
# 	 The current index is 1 for {'occurences': 3, 'current_index': 1, 'indices_in_rows': [2, 97, 114]}
# 	 This will return 97
#
# For [{'label': 'ascending part of duodenum', 'percentage': 0.051}, {'label': 'horizontal part of duodenum', 'percentage': 0.092}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [3, 94, 115]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [3, 94, 115]}
# 	 This will return 3
#
# For [{'label': 'ascending part of duodenum', 'percentage': 0.051}, {'label': 'horizontal part of duodenum', 'percentage': 0.092}] with {'occurences': 3, 'current_index': 1, 'indices_in_rows': [3, 94, 115]}
# 	 The current index is 1 for {'occurences': 3, 'current_index': 1, 'indices_in_rows': [3, 94, 115]}
# 	 This will return 94
#
# For [{'label': 'sigmoid colon', 'percentage': 0.052}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [4, 93, 118]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [4, 93, 118]}
# 	 This will return 4
#
# For [{'label': 'distal part of ileum', 'percentage': 0.267}, {'label': 'ileum', 'percentage': 0.006}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [5, 96, 117]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [5, 96, 117]}
# 	 This will return 5
#
# For [{'label': 'distal part of ileum', 'percentage': 0.267}, {'label': 'ileum', 'percentage': 0.006}] with {'occurences': 3, 'current_index': 1, 'indices_in_rows': [5, 96, 117]}
# 	 The current index is 1 for {'occurences': 3, 'current_index': 1, 'indices_in_rows': [5, 96, 117]}
# 	 This will return 96
#
# For [{'label': 'renal pyramid', 'percentage': 1}] with {'occurences': 5, 'current_index': 0, 'indices_in_rows': [6, 45, 84, 121, 131]}
# 	 The current index is 0 for {'occurences': 5, 'current_index': 0, 'indices_in_rows': [6, 45, 84, 121, 131]}
# 	 This will return 6
#
# For [{'label': 'diaphragmatic surface of spleen', 'percentage': 1}] with {'occurences': 3, 'current_index': 0, 'indices_in_rows': [10, 11, 43]}
# 	 The current index is 0 for {'occurences': 3, 'current_index': 0, 'indices_in_rows': [10, 11, 43]}
# 	 This will return 10
#
# For [{'label': 'diaphragmatic surface of spleen', 'percentage': 1}] with {'occurences': 3, 'current_index': 1, 'indices_in_rows': [10, 11, 43]}
# 	 The current index is 1 for {'occurences': 3, 'current_index': 1, 'indices_in_rows': [10, 11, 43]}
# 	 This will return 11
#
# For [{'label': 'hilum of spleen', 'percentage': 0.006}, {'label': 'diaphragmatic surface of spleen', 'percentage': 1}] with {'occurences': 2, 'current_index': 0, 'indices_in_rows': [12, 123]}
# 	 The current index is 0 for {'occurences': 2, 'current_index': 0, 'indices_in_rows': [12, 123]}
# 	 This will return 12
#
# For [{'label': 'hilum of spleen', 'percentage': 0.006}, {'label': 'diaphragmatic surface of spleen', 'percentage': 1}] with {'occurences': 2, 'current_index': 1, 'indices_in_rows': [12, 123]}
# 	 The current index is 1 for {'occurences': 2, 'current_index': 1, 'indices_in_rows': [12, 123]}
# 	 This will return 123
#
# For [{'label': 'heart left ventricle', 'percentage': 0.813}] with {'occurences': 4, 'current_index': 0, 'indices_in_rows': [15, 17, 124, 147]}
# 	 The current index is 0 for {'occurences': 4, 'current_index': 0, 'indices_in_rows': [15, 17, 124, 147]}
# 	 This will return 15
#
# For [{'label': 'heart left ventricle', 'percentage': 0.886}] with {'occurences': 5, 'current_index': 0, 'indices_in_rows': [16, 42, 60, 125, 171]}
# 	 The current index is 0 for {'occurences': 5, 'current_index': 0, 'indices_in_rows': [16, 42, 60, 125, 171]}
# 	 This will return 16
#
# For [{'label': 'heart left ventricle', 'percentage': 0.813}] with {'occurences': 4, 'current_index': 1, 'indices_in_rows': [15, 17, 124, 147]}
# 	 The current index is 1 for {'occurences': 4, 'current_index': 1, 'indices_in_rows': [15, 17, 124, 147]}
# 	 This will return 17
#
# For [{'label': 'descending colon', 'percentage': 0.29}] with {'occurences': 7, 'current_index': 0, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 The current index is 0 for {'occurences': 7, 'current_index': 0, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 This will return 18
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 19
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 33
#
# For [{'label': 'distal part of ileum', 'percentage': 0.469}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 This will return 20
#
# For [{'label': 'jejunum', 'percentage': 0.343}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 This will return 21
#
# For [{'label': 'descending colon', 'percentage': 0.29}] with {'occurences': 7, 'current_index': 1, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 The current index is 1 for {'occurences': 7, 'current_index': 1, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 This will return 22
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 23
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 28
#
# For [{'label': 'ascending colon', 'percentage': 0.326}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 This will return 24
#
# For [{'label': 'descending part of duodenum', 'percentage': 0.33}] with {'occurences': 6, 'current_index': 0, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 The current index is 0 for {'occurences': 6, 'current_index': 0, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 This will return 25
#
# For [{'label': 'jejunum', 'percentage': 0.343}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 This will return 26
#
# For [{'label': 'distal part of ileum', 'percentage': 0.469}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 This will return 27
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 40
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 3, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 3 for {'occurences': 6, 'current_index': 3, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 50
#
# For [{'label': 'ascending colon', 'percentage': 0.326}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 This will return 29
#
# For [{'label': 'transverse colon', 'percentage': 0.536}] with {'occurences': 5, 'current_index': 0, 'indices_in_rows': [30, 34, 52, 68, 106]}
# 	 The current index is 0 for {'occurences': 5, 'current_index': 0, 'indices_in_rows': [30, 34, 52, 68, 106]}
# 	 This will return 30
#
# For [{'label': 'descending colon', 'percentage': 0.29}] with {'occurences': 7, 'current_index': 2, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 The current index is 2 for {'occurences': 7, 'current_index': 2, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 This will return 31
#
# For [{'label': 'descending part of duodenum', 'percentage': 0.33}] with {'occurences': 6, 'current_index': 1, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 The current index is 1 for {'occurences': 6, 'current_index': 1, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 This will return 32
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 38
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 3, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 3 for {'occurences': 6, 'current_index': 3, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 56
#
# For [{'label': 'transverse colon', 'percentage': 0.536}] with {'occurences': 5, 'current_index': 1, 'indices_in_rows': [30, 34, 52, 68, 106]}
# 	 The current index is 1 for {'occurences': 5, 'current_index': 1, 'indices_in_rows': [30, 34, 52, 68, 106]}
# 	 This will return 34
#
# For [{'label': 'descending colon', 'percentage': 0.29}] with {'occurences': 7, 'current_index': 3, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 The current index is 3 for {'occurences': 7, 'current_index': 3, 'indices_in_rows': [18, 22, 31, 35, 55, 65, 103]}
# 	 This will return 35
#
# For [{'label': 'descending part of duodenum', 'percentage': 0.33}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [25, 32, 36, 51, 63, 108]}
# 	 This will return 36
#
# For [{'label': 'distal part of ileum', 'percentage': 0.469}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [20, 27, 37, 54, 66, 107]}
# 	 This will return 37
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 4, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 4 for {'occurences': 6, 'current_index': 4, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 64
#
# For [{'label': 'horizontal part of duodenum', 'percentage': 0.26}, {'label': 'ascending part of duodenum', 'percentage': 0.108}] with {'occurences': 6, 'current_index': 5, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 The current index is 5 for {'occurences': 6, 'current_index': 5, 'indices_in_rows': [19, 33, 38, 56, 64, 105]}
# 	 This will return 105
#
# For [{'label': 'jejunum', 'percentage': 0.343}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [21, 26, 39, 53, 67, 109]}
# 	 This will return 39
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 4, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 4 for {'occurences': 6, 'current_index': 4, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 61
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 5, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 5 for {'occurences': 6, 'current_index': 5, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 This will return 104
#
# For [{'label': 'ascending colon', 'percentage': 0.326}] with {'occurences': 6, 'current_index': 2, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 The current index is 2 for {'occurences': 6, 'current_index': 2, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 This will return 41
#
# For [{'label': 'heart left ventricle', 'percentage': 0.886}] with {'occurences': 5, 'current_index': 1, 'indices_in_rows': [16, 42, 60, 125, 171]}
# 	 The current index is 1 for {'occurences': 5, 'current_index': 1, 'indices_in_rows': [16, 42, 60, 125, 171]}
# 	 This will return 42
#
# For [{'label': 'diaphragmatic surface of spleen', 'percentage': 1}] with {'occurences': 3, 'current_index': 2, 'indices_in_rows': [10, 11, 43]}
# 	 The current index is 2 for {'occurences': 3, 'current_index': 2, 'indices_in_rows': [10, 11, 43]}
# 	 This will return 43
#
# For [{'label': 'outer cortex of kidney', 'percentage': 1}] with {'occurences': 13, 'current_index': 0, 'indices_in_rows': [44, 70, 71, 101, 110, 122, 127, 134, 158, 159, 168, 169, 170]}
# 	 The current index is 0 for {'occurences': 13, 'current_index': 0, 'indices_in_rows': [44, 70, 71, 101, 110, 122, 127, 134, 158, 159, 168, 169, 170]}
# 	 This will return 44
#
# For [{'label': 'renal pyramid', 'percentage': 1}] with {'occurences': 5, 'current_index': 1, 'indices_in_rows': [6, 45, 84, 121, 131]}
# 	 The current index is 1 for {'occurences': 5, 'current_index': 1, 'indices_in_rows': [6, 45, 84, 121, 131]}
# 	 This will return 45
#
# For [{'label': 'ascending colon', 'percentage': 0.326}] with {'occurences': 6, 'current_index': 3, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 The current index is 3 for {'occurences': 6, 'current_index': 3, 'indices_in_rows': [24, 29, 41, 49, 62, 102]}
# 	 This will return 49
#
# For [{'label': 'sigmoid colon', 'percentage': 0.23}, {'label': 'rectum', 'percentage': 0.006}] with {'occurences': 6, 'current_index': 6, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# 	 The current index is 6 for {'occurences': 6, 'current_index': 6, 'indices_in_rows': [23, 28, 40, 50, 61, 104]}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[220], line 116
#     114 print(f'For {str(row)} with {multiple_as_item_combinations[str(row)]}')
#     115 print(f'\t The current index is {current} for {multiple_as_item_combinations[str(row)]}')
# --> 116 print(f'\t This will return ' + str(multiple_as_item_combinations[str(row)]['indices_in_rows'][current]))
#     117 print()
#     118 i_in_row = multiple_as_item_combinations[str(row)]['indices_in_rows'][current]
#
# IndexError: list index out of range

# %% [markdown]
# ## Prepare for export

# %%
# remove columns 
remove = ['samples', 'rui_location_id', 'datasets']
for key in remove:
  result.pop(key)

# %% [markdown]
# ## Export to CSV

# %%
# remove columns before export
result.pop('dataset_id')

df = pd.DataFrame.from_dict(result)

# # Export DataFrame to CSV
df.to_csv('output/umap_as_percentage.csv', index=False)
